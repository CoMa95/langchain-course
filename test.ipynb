# %%
from dotenv import load_dotenv
import os

from langchain_openai import ChatOpenAI

load_dotenv()
# Out:
# True

# %%
import tavily

# %%
print(os.getenv('OPEN_API_KEY'))
# Out:
# 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

# %%
llm = ChatOpenAI(api_key=os.getenv('OPEN_API_KEY'))
